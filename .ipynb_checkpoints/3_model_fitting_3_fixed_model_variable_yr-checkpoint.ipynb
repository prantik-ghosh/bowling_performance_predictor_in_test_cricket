# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %%
def fit_model_for_yrs(file, model, test_yr_from, test_yr_to,
                      show_feat_imp, show_mse, show_graph1, show_graph2, show_graph3):
    print('++++++++++ MODEL ++++++++++')
    print(model)
    print('++++++++++ MODEL ++++++++++')
    df = pd.read_csv(file)
    
    features = ['year1_wkts_pm', 'year2_wkts_pm', 'year3_wkts_pm', 'year4_wkts_pm', 'year5_wkts_pm',
                'bowl_home_adv', 'ground_bowl_typ']
    target = 'wkts'
    
    exp_var_tot_train = 0
    exp_var_tot_test = 0
    
    for test_yr in range(test_yr_from, test_yr_to+1):
        print('')
        #print("*********************************************")
        print("************** TEST YEAR: " + str(test_yr) + " **************")
        #print("*********************************************")
        
        mask_test = (df.year == test_yr)
        mask_train = (df.year >= test_yr-6) & (df.year <= test_yr-1)
        
        X_train = df[mask_train][features]
        y_train = df[mask_train][target]
        X_test = df[mask_test][features]
        y_test = df[mask_test][target]
        
        model.fit(X_train, y_train)
        
        if (show_feat_imp):
            print('')
            print('Feature Importance:')
            feature_importance = {}
            for label, importance in zip(X_train.columns, model.feature_importances_):
                feature_importance[label] = importance
            print("Sorted Feature Importance:")
            sorted_feature_imp = sorted(feature_importance.items(), key=lambda x: (-x[1]))
            for e in sorted_feature_imp:
                print(e)
            
        y_pred_train = model.predict(X_train)
        y_pred_test = model.predict(X_test)
        
        df_train = pd.concat([df[mask_train][['player','wkts','year1_wkts_pm']].reset_index(),
                              pd.DataFrame(y_pred_train).reset_index()],axis=1,)
        df_train = df_train.drop('index',axis=1)
        df_train.columns = ['player','wkts','wkts_baseline','wkts_exp']
        df_train_by_player = df_train.groupby('player').sum()
        
        df_test = pd.concat([df[mask_test][['player','wkts','year1_wkts_pm']].reset_index(),
                             pd.DataFrame(y_pred_test).reset_index()],axis=1,)
        df_test = df_test.drop('index',axis=1)
        df_test.columns = ['player','wkts','wkts_baseline','wkts_exp']
        df_test_by_player = df_test.groupby('player').sum()
        
        exp_var_tot_train += explained_variance_score(df_train_by_player.wkts, df_train_by_player.wkts_exp)
        exp_var_tot_test += explained_variance_score(df_test_by_player.wkts, df_test_by_player.wkts_exp)
        
        print(' ')
        print('Explained Variance (Train): ' + str(explained_variance_score(df_train_by_player.wkts,
                                                                            df_train_by_player.wkts_exp)))
        print('Explained Variance (Test): ' + str(explained_variance_score(df_test_by_player.wkts,
                                                                           df_test_by_player.wkts_exp)))
        print('----')
        if (show_mse):
            print('Mean Squared Error (Train): ' + str(mean_squared_error(df_train_by_player.wkts,
                                                                          df_train_by_player.wkts_exp)))
            print('Mean Squared Error (Test): ' + str(mean_squared_error(df_test_by_player.wkts,
                                                                         df_test_by_player.wkts_exp)))
            print('----')
        
        if (show_graph1):
            df_test_by_player.plot(kind='scatter',x='wkts',y='wkts_exp',figsize=(7,5))
            plt.title("Actual vs Expected #Wkts by Player")
            plt.show()
        
        if (show_graph2):
            df_test_by_player[['wkts','wkts_exp']].plot(figsize=(12,5))
            plt.title("Actual and Expected #Wkts by Player")
            plt.show()
        
        if (show_graph3):
            df_test_by_player['residual'] = df_test_by_player.wkts - df_test_by_player.wkts_exp
            df_sorted = df_test_by_player.sort_values(['wkts','residual'])
            df_sorted.plot(kind='scatter',x='wkts',y='residual',figsize=(8,5),c='m')
            plt.title("Actual #Wkts by Player vs Residual")
            plt.show()

        print(' ')
        
    print('========== AVERAGE EXPLAINED VARIANCE ==========')
    print('Train: ' + str(exp_var_tot_train/(test_yr_to - test_yr_from+1)))
    print('Test: ' + str(exp_var_tot_test/(test_yr_to - test_yr_from+1)))
    print('========== AVERAGE EXPLAINED VARIANCE ==========')
    print('')

# %%
input_file = 'data/bowling_data_enhanced.csv'
model = GradientBoostingRegressor(learning_rate=0.01, n_estimators=300, max_depth=3, max_features=2,
                                  subsample=0.5, verbose=0, random_state=10)
fit_model_for_yrs(input_file, model, 2011, 2016, True, True, True, True, True)
# Out:
# ++++++++++ MODEL ++++++++++
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.01, loss='ls', max_depth=3, max_features=2,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=300, presort='auto', random_state=10,
#              subsample=0.5, verbose=0, warm_start=False)
# ++++++++++ MODEL ++++++++++
#
# ************** TEST YEAR: 2011 **************
#
# Feature Importance:
# Sorted Feature Importance:
# ('year1_wkts_pm', 0.22316102034368324)
# ('ground_bowl_typ', 0.17525557966678768)
# ('year3_wkts_pm', 0.13441313769981791)
# ('bowl_home_adv', 0.12894090149135051)
# ('year2_wkts_pm', 0.12869562070666229)
# ('year4_wkts_pm', 0.12554356573052666)
# ('year5_wkts_pm', 0.083990174361171469)
#
# Explained Variance (Train): 0.9524467966
# Explained Variance (Test): 0.696227782705
# ----
# Mean Squared Error (Train): 75.2329887412
# Mean Squared Error (Test): 33.5297164056
# ----
#
#
# ************** TEST YEAR: 2012 **************
#
# Feature Importance:
# Sorted Feature Importance:
# ('year1_wkts_pm', 0.20307878744445565)
# ('ground_bowl_typ', 0.1761247153467646)
# ('year2_wkts_pm', 0.15705242308300776)
# ('year3_wkts_pm', 0.14211350999244773)
# ('bowl_home_adv', 0.12313967985557944)
# ('year4_wkts_pm', 0.12120591298684234)
# ('year5_wkts_pm', 0.077284971290902713)
#
# Explained Variance (Train): 0.949596801433
# Explained Variance (Test): 0.751116277303
# ----
# Mean Squared Error (Train): 73.5434712926
# Mean Squared Error (Test): 42.0957372876
# ----
#
#
# ************** TEST YEAR: 2013 **************
#
# Feature Importance:
# Sorted Feature Importance:
# ('year1_wkts_pm', 0.21534330667873058)
# ('ground_bowl_typ', 0.20921812926327885)
# ('year2_wkts_pm', 0.16357116098018265)
# ('bowl_home_adv', 0.1334797829412262)
# ('year3_wkts_pm', 0.1111459187426001)
# ('year4_wkts_pm', 0.086780643799821505)
# ('year5_wkts_pm', 0.080461057594160112)
#
# Explained Variance (Train): 0.949031801109
# Explained Variance (Test): 0.873333387418
# ----
# Mean Squared Error (Train): 81.2043301603
# Mean Squared Error (Test): 24.2767482318
# ----
#
#
# ************** TEST YEAR: 2014 **************
#
# Feature Importance:
# Sorted Feature Importance:
# ('ground_bowl_typ', 0.21321520882702139)
# ('year1_wkts_pm', 0.21235107608843135)
# ('year2_wkts_pm', 0.16546894006917745)
# ('bowl_home_adv', 0.1332780278648642)
# ('year3_wkts_pm', 0.11599621748334611)
# ('year4_wkts_pm', 0.088515771886896202)
# ('year5_wkts_pm', 0.071174757780263401)
#
# Explained Variance (Train): 0.956682440071
# Explained Variance (Test): 0.77386797092
# ----
# Mean Squared Error (Train): 80.5984991403
# Mean Squared Error (Test): 22.7785303734
# ----
#
#
# ************** TEST YEAR: 2015 **************
#
# Feature Importance:
# Sorted Feature Importance:
# ('ground_bowl_typ', 0.22920426735528215)
# ('year1_wkts_pm', 0.20529252727633576)
# ('year2_wkts_pm', 0.16451036644992473)
# ('bowl_home_adv', 0.1336602818930597)
# ('year3_wkts_pm', 0.11803115843017396)
# ('year4_wkts_pm', 0.078251530525975402)
# ('year5_wkts_pm', 0.071049868069248207)
#
# Explained Variance (Train): 0.964758131664
# Explained Variance (Test): 0.819785170646
# ----
# Mean Squared Error (Train): 61.5626339871
# Mean Squared Error (Test): 29.4710543083
# ----
#
#
# ************** TEST YEAR: 2016 **************
#
# Feature Importance:
# Sorted Feature Importance:
# ('ground_bowl_typ', 0.23665853240394591)
# ('year1_wkts_pm', 0.17270876189368317)
# ('year2_wkts_pm', 0.16644063632587991)
# ('bowl_home_adv', 0.13178596674895374)
# ('year3_wkts_pm', 0.12992751044112841)
# ('year4_wkts_pm', 0.097764130448528025)
# ('year5_wkts_pm', 0.064714461737880841)
#
# Explained Variance (Train): 0.967936773775
# Explained Variance (Test): 0.754879234626
# ----
# Mean Squared Error (Train): 57.1608881574
# Mean Squared Error (Test): 41.211564115
# ----
#
# ========== AVERAGE EXPLAINED VARIANCE ==========
# Train: 0.956742124109
# Test: 0.77820163727
# ========== AVERAGE EXPLAINED VARIANCE ==========

# %%
input_file = 'data/bowling_data_enhanced.csv'
model1 = GradientBoostingRegressor(learning_rate=0.01, n_estimators=300, max_depth=3, max_features=2,
                                   subsample=0.5, verbose=0, random_state=10)
model2 = GradientBoostingRegressor(learning_rate=0.005, n_estimators=300, max_depth=3, max_features=2,
                                   subsample=0.5, verbose=0, random_state=10)
model3 = GradientBoostingRegressor(learning_rate=0.01, n_estimators=100, max_depth=3, max_features=2,
                                   subsample=0.5, verbose=0, random_state=10)
model4 = GradientBoostingRegressor(learning_rate=0.01, n_estimators=300, max_depth=2, max_features=2,
                                   subsample=0.5, verbose=0, random_state=10)
models = [model1, model2, model3, model4]

for model in models:
    fit_model_for_yrs(input_file, model, 2011, 2016, False, False, False, False, False)
# Out:
# ++++++++++ MODEL ++++++++++
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.01, loss='ls', max_depth=3, max_features=2,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=300, presort='auto', random_state=10,
#              subsample=0.5, verbose=0, warm_start=False)
# ++++++++++ MODEL ++++++++++
#
# ************** TEST YEAR: 2011 **************
#
# Explained Variance (Train): 0.9524467966
# Explained Variance (Test): 0.696227782705
# ----
#
#
# ************** TEST YEAR: 2012 **************
#
# Explained Variance (Train): 0.949596801433
# Explained Variance (Test): 0.751116277303
# ----
#
#
# ************** TEST YEAR: 2013 **************
#
# Explained Variance (Train): 0.949031801109
# Explained Variance (Test): 0.873333387418
# ----
#
#
# ************** TEST YEAR: 2014 **************
#
# Explained Variance (Train): 0.956682440071
# Explained Variance (Test): 0.77386797092
# ----
#
#
# ************** TEST YEAR: 2015 **************
#
# Explained Variance (Train): 0.964758131664
# Explained Variance (Test): 0.819785170646
# ----
#
#
# ************** TEST YEAR: 2016 **************
#
# Explained Variance (Train): 0.967936773775
# Explained Variance (Test): 0.754879234626
# ----
#
# ========== AVERAGE EXPLAINED VARIANCE ==========
# Train: 0.956742124109
# Test: 0.77820163727
# ========== AVERAGE EXPLAINED VARIANCE ==========
#
# ++++++++++ MODEL ++++++++++
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.005, loss='ls', max_depth=3, max_features=2,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=300, presort='auto', random_state=10,
#              subsample=0.5, verbose=0, warm_start=False)
# ++++++++++ MODEL ++++++++++
#
# ************** TEST YEAR: 2011 **************
#
# Explained Variance (Train): 0.93425501082
# Explained Variance (Test): 0.708633987991
# ----
#
#
# ************** TEST YEAR: 2012 **************
#
# Explained Variance (Train): 0.933391385482
# Explained Variance (Test): 0.748171093503
# ----
#
#
# ************** TEST YEAR: 2013 **************
#
# Explained Variance (Train): 0.931021245747
# Explained Variance (Test): 0.860619472041
# ----
#
#
# ************** TEST YEAR: 2014 **************
#
# Explained Variance (Train): 0.940754279997
# Explained Variance (Test): 0.785297799058
# ----
#
#
# ************** TEST YEAR: 2015 **************
#
# Explained Variance (Train): 0.949801982609
# Explained Variance (Test): 0.800082884099
# ----
#
#
# ************** TEST YEAR: 2016 **************
#
# Explained Variance (Train): 0.952683369631
# Explained Variance (Test): 0.735348831452
# ----
#
# ========== AVERAGE EXPLAINED VARIANCE ==========
# Train: 0.940317879048
# Test: 0.773025678024
# ========== AVERAGE EXPLAINED VARIANCE ==========
#
# ++++++++++ MODEL ++++++++++
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.01, loss='ls', max_depth=3, max_features=2,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=10,
#              subsample=0.5, verbose=0, warm_start=False)
# ++++++++++ MODEL ++++++++++
#
# ************** TEST YEAR: 2011 **************
#
# Explained Variance (Train): 0.920122512251
# Explained Variance (Test): 0.713528056724
# ----
#
#
# ************** TEST YEAR: 2012 **************
#
# Explained Variance (Train): 0.921013560061
# Explained Variance (Test): 0.745812764896
# ----
#
#
# ************** TEST YEAR: 2013 **************
#
# Explained Variance (Train): 0.919438078655
# Explained Variance (Test): 0.852360039589
# ----
#
#
# ************** TEST YEAR: 2014 **************
#
# Explained Variance (Train): 0.92998311305
# Explained Variance (Test): 0.786231566038
# ----
#
#
# ************** TEST YEAR: 2015 **************
#
# Explained Variance (Train): 0.939447288892
# Explained Variance (Test): 0.794898689149
# ----
#
#
# ************** TEST YEAR: 2016 **************
#
# Explained Variance (Train): 0.943501466242
# Explained Variance (Test): 0.720378561393
# ----
#
# ========== AVERAGE EXPLAINED VARIANCE ==========
# Train: 0.928917669859
# Test: 0.768868279632
# ========== AVERAGE EXPLAINED VARIANCE ==========
#
# ++++++++++ MODEL ++++++++++
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.01, loss='ls', max_depth=2, max_features=2,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=300, presort='auto', random_state=10,
#              subsample=0.5, verbose=0, warm_start=False)
# ++++++++++ MODEL ++++++++++
#
# ************** TEST YEAR: 2011 **************
#
# Explained Variance (Train): 0.942559807552
# Explained Variance (Test): 0.698326130356
# ----
#
#
# ************** TEST YEAR: 2012 **************
#
# Explained Variance (Train): 0.937957507815
# Explained Variance (Test): 0.752930271165
# ----
#
#
# ************** TEST YEAR: 2013 **************
#
# Explained Variance (Train): 0.935712282217
# Explained Variance (Test): 0.863640089385
# ----
#
#
# ************** TEST YEAR: 2014 **************
#
# Explained Variance (Train): 0.945686743933
# Explained Variance (Test): 0.780024727517
# ----
#
#
# ************** TEST YEAR: 2015 **************
#
# Explained Variance (Train): 0.955522739912
# Explained Variance (Test): 0.80082181347
# ----
#
#
# ************** TEST YEAR: 2016 **************
#
# Explained Variance (Train): 0.958513918941
# Explained Variance (Test): 0.730506129778
# ----
#
# ========== AVERAGE EXPLAINED VARIANCE ==========
# Train: 0.945992166728
# Test: 0.771041526945
# ========== AVERAGE EXPLAINED VARIANCE ==========
